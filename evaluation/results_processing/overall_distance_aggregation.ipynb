# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

# %% [markdown]
# ## Analyzing number of paths

# %%
## Gathering it all together
def aggregating_means(dir_path):
    means_avoid = pd.read_csv(os.path.join(dir_path, 'means_avoid.csv'), index_col=0)
    means_neutral = pd.read_csv(os.path.join(dir_path, 'means_neutral.csv'),index_col=0)
    means_paved = pd.read_csv(os.path.join(dir_path, 'means_paved.csv'),index_col=0)
    means_prefer = pd.read_csv(os.path.join(dir_path, 'means_prefer.csv'),index_col=0)
    
    means = pd.concat([means_neutral,means_avoid,means_paved, means_prefer])
    means["Setting"] = ["neutral","avoid","prefer","paved"]
    means.set_index("Setting",inplace=True)
    return means




distances = [2000,5000,10000,15000]# ,20000

base_path = "/Users/sofiiashome/Documents/Studying at WU/Bachelor's Thesis/Bachelor Thesis Coding/LoopBuddy/evaluation/results/overall_results"
save_dir = os.path.join(base_path, "distance_aggregated")

for i in distances:
    path = os.path.join(base_path, f"overall_{i}")
    means = aggregating_means(path)
    save_path = os.path.join(save_dir, f"means_{i}.csv")
    means.to_csv(save_path)
    

# aggregating fails:

f2000 = pd.read_csv(os.path.join(os.path.join(base_path, f"overall_{2000}"), 'failed.csv'), index_col=0)
f5000 = pd.read_csv(os.path.join(os.path.join(base_path, f"overall_{5000}"), 'failed.csv'), index_col=0)
f10000 = pd.read_csv(os.path.join(os.path.join(base_path, f"overall_{10000}"), 'failed.csv'), index_col=0)
f15000 = pd.read_csv(os.path.join(os.path.join(base_path, f"overall_{15000}"), 'failed.csv'), index_col=0)


fails_agg = pd.concat([f2000,f5000,f10000,f15000])#,f20000
fails_agg["Distance"] = distances
fails_agg.set_index("Distance",inplace=True)
fails_agg.to_csv(os.path.join(os.path.join(save_dir, f"fails_agg.csv")))

# %%
distances = [2000, 5000, 10000, 15000]
base_path = "/Users/sofiiashome/Documents/Studying at WU/Bachelor's Thesis/Bachelor Thesis Coding/LoopBuddy/evaluation/results/overall_results/overall_distance_aggregated"

all_data = []

for dist in distances:
    means_path = os.path.join(base_path, f"means_{dist}.csv")
    df = pd.read_csv(means_path, index_col=0)
    df.reset_index(inplace=True)  # brings 'Setting' back as column
    df.insert(0, "Distance", dist)  # add distance column at front
    df.rename(columns={"Setting": "State"}, inplace=True)  # rename for clarity
    all_data.append(df)

# Combine everything
final_df = pd.concat(all_data)
final_df.to_csv(base_path+"means_combined_distance_state_only.csv", index=False)
display(final_df)
# Out:
#    Distance    State  Elapsed time  N Paths  N stoplights   N steps  \
# 0      2000  neutral      3.284189     6.48      3.962157  0.000000
# 1      2000    avoid      3.364971     6.49      3.443444  0.000000
# 2      2000   prefer      3.263711     6.56      3.981462  0.000000
# 3      2000    paved      2.803088     6.13      4.684141  0.000000
# 0      5000  neutral     12.309361     6.73     12.774637  0.012048
# 1      5000    avoid     11.638411     5.92     10.583970  0.000000
# 2      5000   prefer     11.170227     5.54     13.067860  0.012500
# 3      5000    paved      6.310393     3.07     14.617994  0.000000
# 0     10000  neutral     57.703034     8.28     28.627830  0.000000
# 1     10000    avoid     51.988224     7.26     22.438839  0.000000
# 2     10000   prefer     50.204767     6.41     30.366459  0.000000
# 3     10000    paved     18.528770     1.62     37.886990  0.000000
# 0     15000  neutral    137.479953     8.38     48.336502  0.023529
# 1     15000    avoid    120.524072     5.77     37.224670  0.000000
# 2     15000   prefer    116.990040     5.88     51.995905  0.000000
# 3     15000    paved     34.502235     0.62     60.106061  0.000000
#
#    N paved edges  N unpaved edges  N unknown edge surfaces  Path badness
# 0      13.435766         0.683622                19.973921           NaN
# 1      13.376488         0.698532                20.372479     13.177934
# 2      14.001483         0.631273                19.755953     35.215452
# 3      13.734972         0.756399                20.278963    616.728118
# 0      35.338756         1.261673                45.049035           NaN
# 1      36.927306         1.219838                44.889700     41.811108
# 2      38.855550         0.975833                42.675027     75.718130
# 3      35.541717         1.149783                45.134462   1511.916598
# 0      74.778228         2.095853                84.849656           NaN
# 1      74.098797         2.222355                86.491107     97.814349
# 2      79.230512         1.738245                81.506788    146.661290
# 3      81.072682         2.520168                84.497399   2953.120208
# 0     117.024005         2.948803               123.774453           NaN
# 1     116.080697         3.596827               126.055474    161.180367
# 2     130.810195         2.685853               120.706310    206.947576
# 3     117.262626         2.290404               125.803030   4410.161705
